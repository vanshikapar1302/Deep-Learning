# %%
import torch
import torch.nn as nn

# %%
torch.manual_seed(4.2)
inputs=torch.tensor([1.0,2.0,3.0])

# %%
neuron=nn.Linear(in_features=3,out_features=1)

# %%
output=neuron(inputs)

# %%
output
# Out:
# tensor([-0.5479], grad_fn=<ViewBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[-0.0737, -0.0594, -0.1965]], requires_grad=True)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.2342], requires_grad=True)

# %%
neuron.weight @ inputs+neuron.bias
# Out:
# tensor([-0.5479], grad_fn=<AddBackward0>)
